# %%
import sys
main_path = "../../.."
sys.path.append(main_path)

# importing modules
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
from src.scripts.common_figures import Figures

# %%
figures = Figures()
sns.set_context('poster', font_scale=0.8)

# %%
model_scores_path = f"{main_path}/data/processed/model_scores"

with open(f"{main_path}/data/processed/model_scores/best_scores.pkl", 'rb') as f:
    metric_results = pickle.load(f)

with open(f"{main_path}/data/processed/model_scores/best_scores_survival.pkl", 'rb') as f:
    metric_results_survival = pickle.load(f)

# %% [markdown]
# # Scores For Different Options

# %%
class_names = {'ohe_di':'Approach OHE_DI',
               'ohe_di_fi':'Approach OHE_DI_FI'}

class_names_is_live = {'ohe_di_is_live':'Approach OHE_DI_IS_LIVE',
               'ohe_di_fi_is_live':'Approach OHE_DI_FI_IS_LIVE'}

class_names_live_month_18 = {'ohe_di_live_month_18':'Approach OHE_DI_LIVE_MONTH_18',
               'ohe_di_fi_live_month_18':'Approach OHE_DI_FI_LIVE_MONTH_18'}

class_names_live_month_36 = {'ohe_di_live_month_36':'Approach OHE_DI_LIVE_MONTH_36',
               'ohe_di_fi_live_month_36':'Approach OHE_DI_FI_LIVE_MONTH_36'}

class_names_live_month_54 = {'ohe_di_live_month_54':'Approach OHE_DI_LIVE_MONTH_54',
               'ohe_di_fi_live_month_54':'Approach OHE_DI_FI_LIVE_MONTH_54'}

class_names_live_month_72 = {'ohe_di_live_month_72':'Approach OHE_DI_LIVE_MONTH_72',
               'ohe_di_fi_live_month_72':'Approach OHE_DI_FI_LIVE_MONTH_72'}

class_names_live_month_90 = {'ohe_di_live_month_90':'Approach OHE_DI_LIVE_MONTH_90',
               'ohe_di_fi_live_month_90':'Approach OHE_DI_FI_LIVE_MONTH_90'}

class_names_live_month_108 = {'ohe_di_live_month_108':'Approach OHE_DI_LIVE_MONTH_108',
               'ohe_di_fi_live_month_108':'Approach OHE_DI_FI_LIVE_MONTH_108'}


classifier_names = ['LR', 'RF', 'SVM']

scores = {'ohe_di':[metric_results['ohe_di'][i.lower()]['f1_scores'] for i in classifier_names],
          'ohe_di_fi':[metric_results['ohe_di_fi'][i.lower()]['f1_scores'] for i in classifier_names]}

scores_is_live = {'ohe_di_is_live':[metric_results['ohe_di_is_live'][i.lower()]['f1_scores'] for i in classifier_names],
          'ohe_di_fi_is_live':[metric_results['ohe_di_fi_is_live'][i.lower()]['f1_scores'] for i in classifier_names]}

scores_live_month_18 = {'ohe_di_live_month_18':[metric_results_survival['ohe_di_live_month_18'][i.lower()]['f1_scores'] for i in classifier_names],
          'ohe_di_fi_live_month_18':[metric_results_survival['ohe_di_fi_live_month_18'][i.lower()]['f1_scores'] for i in classifier_names]}

scores_live_month_36 = {'ohe_di_live_month_36':[metric_results_survival['ohe_di_live_month_36'][i.lower()]['f1_scores'] for i in classifier_names],
          'ohe_di_fi_live_month_36':[metric_results_survival['ohe_di_fi_live_month_36'][i.lower()]['f1_scores'] for i in classifier_names]}

scores_live_month_54 = {'ohe_di_live_month_54':[metric_results_survival['ohe_di_live_month_54'][i.lower()]['f1_scores'] for i in classifier_names],
          'ohe_di_fi_live_month_54':[metric_results_survival['ohe_di_fi_live_month_54'][i.lower()]['f1_scores'] for i in classifier_names]}

scores_live_month_72 = {'ohe_di_live_month_72':[metric_results_survival['ohe_di_live_month_72'][i.lower()]['f1_scores'] for i in classifier_names],
          'ohe_di_fi_live_month_72':[metric_results_survival['ohe_di_fi_live_month_72'][i.lower()]['f1_scores'] for i in classifier_names]}

scores_live_month_90 = {'ohe_di_live_month_90':[metric_results_survival['ohe_di_live_month_90'][i.lower()]['f1_scores'] for i in classifier_names],
          'ohe_di_fi_live_month_90':[metric_results_survival['ohe_di_fi_live_month_90'][i.lower()]['f1_scores'] for i in classifier_names]}

scores_live_month_108 = {'ohe_di_live_month_108':[metric_results_survival['ohe_di_live_month_108'][i.lower()]['f1_scores'] for i in classifier_names],
          'ohe_di_fi_live_month_108':[metric_results_survival['ohe_di_fi_live_month_108'][i.lower()]['f1_scores'] for i in classifier_names]}



save = f"{main_path}/figures/paper_figures/png/f1scores_ohe_di_and_ohe_di_fi.png"
paper_figure = f"{main_path}/figures/paper_figures/svg/f1scores_ohe_di_and_ohe_di_fi.svg"
figures.draw_bar_plot(classifier_names, scores, class_names, grid_shape=(1, 2),
                      save=save, paper_figure=paper_figure)

save_is_live = f"{main_path}/figures/paper_figures/png/f1scores_ohe_di_and_ohe_di_fi_is_live.png"
paper_figure_is_live = f"{main_path}/figures/paper_figures/svg/f1scores_ohe_di_and_ohe_di_fi_is_live.svg"
figures.draw_bar_plot(classifier_names, scores_is_live, class_names_is_live, grid_shape=(1, 2),
                      save=save_is_live, paper_figure=paper_figure_is_live)

save_live_month_18 = f"{main_path}/figures/paper_figures/png/f1scores_ohe_di_and_ohe_di_fi_live_month_18.png"
paper_figure_live_month_18 = f"{main_path}/figures/paper_figures/svg/f1scores_ohe_di_and_ohe_di_fi_live_month_18.svg"

save_live_month_36 = f"{main_path}/figures/paper_figures/png/f1scores_ohe_di_and_ohe_di_fi_live_month_36.png"
paper_figure_live_month_36 = f"{main_path}/figures/paper_figures/svg/f1scores_ohe_di_and_ohe_di_fi_live_month_36.svg"

save_live_month_54 = f"{main_path}/figures/paper_figures/png/f1scores_ohe_di_and_ohe_di_fi_live_month_54.png"
paper_figure_live_month_54 = f"{main_path}/figures/paper_figures/svg/f1scores_ohe_di_and_ohe_di_fi_live_month_54.svg"

save_live_month_72 = f"{main_path}/figures/paper_figures/png/f1scores_ohe_di_and_ohe_di_fi_live_month_72.png"
paper_figure_live_month_72 = f"{main_path}/figures/paper_figures/svg/f1scores_ohe_di_and_ohe_di_fi_live_month_72.svg"

save_live_month_90 = f"{main_path}/figures/paper_figures/png/f1scores_ohe_di_and_ohe_di_fi_live_month_90.png"
paper_figure_live_month_90 = f"{main_path}/figures/paper_figures/svg/f1scores_ohe_di_and_ohe_di_fi_live_month_90.svg"

save_live_month_108 = f"{main_path}/figures/paper_figures/png/f1scores_ohe_di_and_ohe_di_fi_live_month_108.png"
paper_figure_live_month_108 = f"{main_path}/figures/paper_figures/svg/f1scores_ohe_di_and_ohe_di_fi_live_month_108.svg"

figures.draw_bar_plot(classifier_names, scores_live_month_18, class_names_live_month_18, grid_shape=(1, 2),
                      save=save_live_month_18, paper_figure=paper_figure_live_month_18)
figures.draw_bar_plot(classifier_names, scores_live_month_36, class_names_live_month_36, grid_shape=(1, 2),
                      save=save_live_month_36, paper_figure=paper_figure_live_month_36)
figures.draw_bar_plot(classifier_names, scores_live_month_54, class_names_live_month_54, grid_shape=(1, 2),
                      save=save_live_month_54, paper_figure=paper_figure_live_month_54)
figures.draw_bar_plot(classifier_names, scores_live_month_72, class_names_live_month_72, grid_shape=(1, 2),
                      save=save_live_month_72, paper_figure=paper_figure_live_month_72)
figures.draw_bar_plot(classifier_names, scores_live_month_90, class_names_live_month_90, grid_shape=(1, 2),
                      save=save_live_month_90, paper_figure=paper_figure_live_month_90)
figures.draw_bar_plot(classifier_names, scores_live_month_108, class_names_live_month_108, grid_shape=(1, 2),
                      save=save_live_month_108, paper_figure=paper_figure_live_month_108)

# %%
class_names = {'cdt_di_ohe':'Approach CDT_DI_OHE',
               'cdt_di_fi_ohe':'Approach CDT_DI_FI_OHE'}

class_names_is_live = {'cdt_di_ohe_is_live':'Approach CDT_DI_OHE_IS_LIVE',
               'cdt_di_fi_ohe_is_live':'Approach CDT_DI_FI_OHE_IS_LIVE'}


class_names_live_month_18 = {'cdt_di_ohe_live_month_18':'Approach CDT_DI_OHE_LIVE_MONTH_18',
               'cdt_di_fi_ohe_live_month_18':'Approach CDT_DI_FI_OHE_LIVE_MONTH_18'}

class_names_live_month_36 = {'cdt_di_ohe_live_month_36':'Approach CDT_DI_OHE_LIVE_MONTH_36',
               'cdt_di_fi_ohe_live_month_36':'Approach CDT_DI_FI_OHE_LIVE_MONTH_36'}

class_names_live_month_54 = {'cdt_di_ohe_live_month_54':'Approach CDT_DI_OHE_LIVE_MONTH_54',
               'cdt_di_fi_ohe_live_month_54':'Approach CDT_DI_FI_OHE_LIVE_MONTH_54'}

class_names_live_month_72 = {'cdt_di_ohe_live_month_72':'Approach CDT_DI_OHE_LIVE_MONTH_72',
               'cdt_di_fi_ohe_live_month_72':'Approach CDT_DI_FI_OHE_LIVE_MONTH_72'}

class_names_live_month_90 = {'cdt_di_ohe_live_month_90':'Approach CDT_DI_OHE_LIVE_MONTH_90',
               'cdt_di_fi_ohe_live_month_90':'Approach CDT_DI_FI_OHE_LIVE_MONTH_90'}

class_names_live_month_108 = {'cdt_di_ohe_live_month_108':'Approach CDT_DI_OHE_LIVE_MONTH_108',
               'cdt_di_fi_ohe_live_month_108':'Approach CDT_DI_FI_OHE_LIVE_MONTH_108'}

classifier_names = ['LR', 'RF', 'SVM']

scores = {'cdt_di_ohe':[metric_results['cdt_di_ohe'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_ohe':[metric_results['cdt_di_fi_ohe'][i.lower()]['f1_scores'] for i in classifier_names]}

scores_is_live = {'cdt_di_ohe_is_live':[metric_results['cdt_di_ohe_is_live'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_ohe_is_live':[metric_results['cdt_di_fi_ohe_is_live'][i.lower()]['f1_scores'] for i in classifier_names]}

scores_live_month_18 = {'cdt_di_ohe_live_month_18':[metric_results_survival['cdt_di_ohe_live_month_18'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_ohe_live_month_18':[metric_results_survival['cdt_di_fi_ohe_live_month_18'][i.lower()]['f1_scores'] for i in classifier_names]}

scores_live_month_36 = {'cdt_di_ohe_live_month_36':[metric_results_survival['cdt_di_ohe_live_month_36'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_ohe_live_month_36':[metric_results_survival['cdt_di_fi_ohe_live_month_36'][i.lower()]['f1_scores'] for i in classifier_names]}

scores_live_month_54 = {'cdt_di_ohe_live_month_54':[metric_results_survival['cdt_di_ohe_live_month_54'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_ohe_live_month_54':[metric_results_survival['cdt_di_fi_ohe_live_month_54'][i.lower()]['f1_scores'] for i in classifier_names]}

scores_live_month_72 = {'cdt_di_ohe_live_month_72':[metric_results_survival['cdt_di_ohe_live_month_72'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_ohe_live_month_72':[metric_results_survival['cdt_di_fi_ohe_live_month_72'][i.lower()]['f1_scores'] for i in classifier_names]}

scores_live_month_90 = {'cdt_di_ohe_live_month_90':[metric_results_survival['cdt_di_ohe_live_month_90'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_ohe_live_month_90':[metric_results_survival['cdt_di_fi_ohe_live_month_90'][i.lower()]['f1_scores'] for i in classifier_names]}

scores_live_month_108 = {'cdt_di_ohe_live_month_108':[metric_results_survival['cdt_di_ohe_live_month_108'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_ohe_live_month_108':[metric_results_survival['cdt_di_fi_ohe_live_month_108'][i.lower()]['f1_scores'] for i in classifier_names]}

save = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe.png"
paper_figure = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe.svg"
figures.draw_bar_plot(classifier_names, scores, class_names, grid_shape=(1, 2), save=save, paper_figure=paper_figure)

save_is_live = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe_is_live.png"
paper_figure_is_live = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe_is_live.svg"
figures.draw_bar_plot(classifier_names, scores_is_live, class_names_is_live, grid_shape=(1, 2), save=save_is_live, paper_figure=paper_figure_is_live)

save_live_month_18 = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe_live_month_18.png"
paper_figure_live_month_18 = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe_live_month_18.svg"
figures.draw_bar_plot(classifier_names, scores_live_month_18, class_names_live_month_18, grid_shape=(1, 2), save=save_live_month_18, paper_figure=paper_figure_live_month_18)


save_live_month_36 = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe_live_month_36.png"
paper_figure_live_month_36 = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe_live_month_36.svg"
figures.draw_bar_plot(classifier_names, scores_live_month_36, class_names_live_month_36, grid_shape=(1, 2), save=save_live_month_36, paper_figure=paper_figure_live_month_36)


save_live_month_54 = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe_live_month_54.png"
paper_figure_live_month_54 = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe_live_month_54.svg"
figures.draw_bar_plot(classifier_names, scores_live_month_54, class_names_live_month_54, grid_shape=(1, 2), save=save_live_month_54, paper_figure=paper_figure_live_month_54)


save_live_month_72 = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe_live_month_72.png"
paper_figure_live_month_72 = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe_live_month_72.svg"
figures.draw_bar_plot(classifier_names, scores_live_month_72, class_names_live_month_72, grid_shape=(1, 2), save=save_live_month_72, paper_figure=paper_figure_live_month_72)



save_live_month_90 = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe_live_month_90.png"
paper_figure_live_month_90 = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe_live_month_90.svg"
figures.draw_bar_plot(classifier_names, scores_live_month_90, class_names_live_month_90, grid_shape=(1, 2), save=save_live_month_90, paper_figure=paper_figure_live_month_90)


save_live_month_108 = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe_live_month_108.png"
paper_figure_live_month_108 = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_ohe_and_cdt_di_fi_ohe_live_month_108.svg"
figures.draw_bar_plot(classifier_names, scores_live_month_108, class_names_live_month_108, grid_shape=(1, 2), save=save_live_month_108, paper_figure=paper_figure_live_month_108)

# %%
class_names = {'cdt_di':'Approach CDT_DI',
               'cdt_di_fi':'Approach CDT_DI_FI'}

classifier_names = ['LR', 'RF', 'SVM']

scores = {'cdt_di':[metric_results['cdt_di'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi':[metric_results['cdt_di_fi'][i.lower()]['f1_scores'] for i in classifier_names]}

save = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_and_cdt_di_fi.png"
paper_figure = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_and_cdt_di_fi.svg"
figures.draw_bar_plot(classifier_names, scores, class_names, grid_shape=(1, 2), save=save, paper_figure=paper_figure)

class_names_is_live = {'cdt_di_is_live':'Approach CDT_DI_IS_LIVE',
               'cdt_di_fi_is_live':'Approach CDT_DI_FI_IS_LIVE'}

scores_is_live = {'cdt_di_is_live':[metric_results['cdt_di_is_live'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_is_live':[metric_results['cdt_di_fi_is_live'][i.lower()]['f1_scores'] for i in classifier_names]}

save_is_live = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_and_cdt_di_fi_is_live.png"
paper_figure_is_live = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_and_cdt_di_fi_is_live.svg"
figures.draw_bar_plot(classifier_names, scores_is_live, class_names_is_live, grid_shape=(1, 2), save=save_is_live, paper_figure=paper_figure_is_live)


class_names_live_month_18 = {'cdt_di_live_month_18':'Approach CDT_DI_LIVE_MONTH_18',
               'cdt_di_fi_live_month_18':'Approach CDT_DI_FI_LIVE_MONTH_18'}

scores_live_month_18 = {'cdt_di_live_month_18':[metric_results_survival['cdt_di_live_month_18'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_live_month_18':[metric_results_survival['cdt_di_fi_live_month_18'][i.lower()]['f1_scores'] for i in classifier_names]}

save_live_month_18 = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_and_cdt_di_fi_live_month_18.png"
paper_figure_live_month_18 = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_and_cdt_di_fi_live_month_18.svg"
figures.draw_bar_plot(classifier_names, scores_live_month_18, class_names_live_month_18, grid_shape=(1, 2), save=save_live_month_18, paper_figure=paper_figure_live_month_18)


class_names_live_month_36 = {'cdt_di_live_month_36':'Approach CDT_DI_LIVE_MONTH_36',
               'cdt_di_fi_live_month_36':'Approach CDT_DI_FI_LIVE_MONTH_36'}

scores_live_month_36 = {'cdt_di_live_month_36':[metric_results_survival['cdt_di_live_month_36'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_live_month_36':[metric_results_survival['cdt_di_fi_live_month_36'][i.lower()]['f1_scores'] for i in classifier_names]}

save_live_month_36 = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_and_cdt_di_fi_live_month_36.png"
paper_figure_live_month_36 = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_and_cdt_di_fi_live_month_36.svg"
figures.draw_bar_plot(classifier_names, scores_live_month_36, class_names_live_month_36, grid_shape=(1, 2), save=save_live_month_36, paper_figure=paper_figure_live_month_36)



class_names_live_month_54 = {'cdt_di_live_month_54':'Approach CDT_DI_LIVE_MONTH_54',
               'cdt_di_fi_live_month_54':'Approach CDT_DI_FI_LIVE_MONTH_54'}

scores_live_month_54 = {'cdt_di_live_month_54':[metric_results_survival['cdt_di_live_month_54'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_live_month_54':[metric_results_survival['cdt_di_fi_live_month_54'][i.lower()]['f1_scores'] for i in classifier_names]}

save_live_month_54 = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_and_cdt_di_fi_live_month_54.png"
paper_figure_live_month_54 = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_and_cdt_di_fi_live_month_54.svg"
figures.draw_bar_plot(classifier_names, scores_live_month_54, class_names_live_month_54, grid_shape=(1, 2), save=save_live_month_54, paper_figure=paper_figure_live_month_54)



class_names_live_month_72 = {'cdt_di_live_month_72':'Approach CDT_DI_LIVE_MONTH_72',
               'cdt_di_fi_live_month_72':'Approach CDT_DI_FI_LIVE_MONTH_72'}

scores_live_month_72 = {'cdt_di_live_month_72':[metric_results_survival['cdt_di_live_month_72'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_live_month_72':[metric_results_survival['cdt_di_fi_live_month_72'][i.lower()]['f1_scores'] for i in classifier_names]}

save_live_month_72 = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_and_cdt_di_fi_live_month_72.png"
paper_figure_live_month_72 = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_and_cdt_di_fi_live_month_72.svg"
figures.draw_bar_plot(classifier_names, scores_live_month_72, class_names_live_month_72, grid_shape=(1, 2), save=save_live_month_72, paper_figure=paper_figure_live_month_72)



class_names_live_month_90 = {'cdt_di_live_month_90':'Approach CDT_DI_LIVE_MONTH_90',
               'cdt_di_fi_live_month_90':'Approach CDT_DI_FI_LIVE_MONTH_90'}

scores_live_month_90 = {'cdt_di_live_month_90':[metric_results_survival['cdt_di_live_month_90'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_live_month_90':[metric_results_survival['cdt_di_fi_live_month_90'][i.lower()]['f1_scores'] for i in classifier_names]}

save_live_month_90 = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_and_cdt_di_fi_live_month_90.png"
paper_figure_live_month_90 = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_and_cdt_di_fi_live_month_90.svg"
figures.draw_bar_plot(classifier_names, scores_live_month_90, class_names_live_month_90, grid_shape=(1, 2), save=save_live_month_90, paper_figure=paper_figure_live_month_90)



class_names_live_month_108 = {'cdt_di_live_month_108':'Approach CDT_DI_LIVE_MONTH_108',
               'cdt_di_fi_live_month_108':'Approach CDT_DI_FI_LIVE_MONTH_108'}

scores_live_month_108 = {'cdt_di_live_month_108':[metric_results_survival['cdt_di_live_month_108'][i.lower()]['f1_scores'] for i in classifier_names],
          'cdt_di_fi_live_month_108':[metric_results_survival['cdt_di_fi_live_month_108'][i.lower()]['f1_scores'] for i in classifier_names]}

save_live_month_108 = f"{main_path}/figures/paper_figures/png/f1scores_cdt_di_and_cdt_di_fi_live_month_108.png"
paper_figure_live_month_108 = f"{main_path}/figures/paper_figures/svg/f1scores_cdt_di_and_cdt_di_fi_live_month_108.svg"
figures.draw_bar_plot(classifier_names, scores_live_month_108, class_names_live_month_108, grid_shape=(1, 2), save=save_live_month_108, paper_figure=paper_figure_live_month_108)
