# %%
import sys
main_path = "../../.."
sys.path.append(main_path)

# importing modules
import os
import pickle
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from src.scripts.common_figures import Figures

# %%
model_scores_path = f"{main_path}/data/processed/model_scores"
os.makedirs(model_scores_path, exist_ok=True)

with open(f"{model_scores_path}/best_scores.pkl", 'rb') as f:
    metric_results = pickle.load(f)
    
with open(f"{model_scores_path}/best_scores_survival.pkl", 'rb') as f:
    metric_results_survival = pickle.load(f)

with open(f"{main_path}/config.yaml", 'r') as f:
    config = yaml.safe_load(f)

# %%
figures = Figures()
sns.set_context('poster', font_scale=0.8)

# %%
roc_scores = {'cdt_di_fi_ohe':[metric_results['cdt_di_fi_ohe']['lr']['rocauc'], metric_results['cdt_di_fi_ohe']['rf']['rocauc'],
                   metric_results['cdt_di_fi_ohe']['svm']['rocauc']]}

class_names = {'cdt_di_fi_ohe':'Approach CDT_DI_FI_OHE'}

classifier_names = ['LR', 'RF', 'SVM']

save = f"{main_path}/figures/paper_figures/png/roccurve_cdt_di_fi_ohe.png"
paper_figure = f"{main_path}/figures/paper_figures/svg/roccurve_cdt_di_fi_ohe.svg"
figures.draw_rocauc_curve(classifier_names, roc_scores, class_names, grid_shape=(1, 1),
                         save=save, paper_figure=paper_figure)



roc_scores_is_live = {'cdt_di_fi_ohe_is_live':[metric_results['cdt_di_fi_ohe_is_live']['lr']['rocauc'], metric_results['cdt_di_fi_ohe_is_live']['rf']['rocauc'],
                   metric_results['cdt_di_fi_ohe_is_live']['svm']['rocauc']]}

class_names_is_live = {'cdt_di_fi_ohe_is_live':'Approach CDT_DI_FI_OHE_IS_LIVE'}


save_is_live = f"{main_path}/figures/paper_figures/png/roccurve_cdt_di_fi_ohe_is_live.png"
paper_figure_is_live = f"{main_path}/figures/paper_figures/svg/roccurve_cdt_di_fi_ohe_is_live.svg"
figures.draw_rocauc_curve(classifier_names, roc_scores_is_live, class_names_is_live, grid_shape=(1, 1),
                         save=save_is_live, paper_figure=paper_figure_is_live)



roc_scores_live_month_18 = {'cdt_di_fi_ohe_live_month_18':[metric_results_survival['cdt_di_fi_ohe_live_month_18']['lr']['rocauc'], metric_results_survival['cdt_di_fi_ohe_live_month_18']['rf']['rocauc'],
                   metric_results_survival['cdt_di_fi_ohe_live_month_18']['svm']['rocauc']]}

class_names_live_month_18 = {'cdt_di_fi_ohe_live_month_18':'Approach CDT_DI_FI_OHE_LIVE_MONTH_18'}


save_live_month_18 = f"{main_path}/figures/paper_figures/png/roccurve_cdt_di_fi_ohe_live_month_18.png"
paper_figure_live_month_18 = f"{main_path}/figures/paper_figures/svg/roccurve_cdt_di_fi_ohe_live_month_18.svg"
figures.draw_rocauc_curve(classifier_names, roc_scores_live_month_18, class_names_live_month_18, grid_shape=(1, 1),
                         save=save_live_month_18, paper_figure=paper_figure_live_month_18)


roc_scores_live_month_36 = {'cdt_di_fi_ohe_live_month_36':[metric_results_survival['cdt_di_fi_ohe_live_month_36']['lr']['rocauc'], metric_results_survival['cdt_di_fi_ohe_live_month_36']['rf']['rocauc'],
                   metric_results_survival['cdt_di_fi_ohe_live_month_36']['svm']['rocauc']]}

class_names_live_month_36 = {'cdt_di_fi_ohe_live_month_36':'Approach CDT_DI_FI_OHE_LIVE_MONTH_36'}


save_live_month_36 = f"{main_path}/figures/paper_figures/png/roccurve_cdt_di_fi_ohe_live_month_36.png"
paper_figure_live_month_36 = f"{main_path}/figures/paper_figures/svg/roccurve_cdt_di_fi_ohe_live_month_36.svg"
figures.draw_rocauc_curve(classifier_names, roc_scores_live_month_36, class_names_live_month_36, grid_shape=(1, 1),
                         save=save_live_month_36, paper_figure=paper_figure_live_month_36)


roc_scores_live_month_54 = {'cdt_di_fi_ohe_live_month_54':[metric_results_survival['cdt_di_fi_ohe_live_month_54']['lr']['rocauc'], metric_results_survival['cdt_di_fi_ohe_live_month_54']['rf']['rocauc'],
                   metric_results_survival['cdt_di_fi_ohe_live_month_54']['svm']['rocauc']]}

class_names_live_month_54 = {'cdt_di_fi_ohe_live_month_54':'Approach CDT_DI_FI_OHE_LIVE_MONTH_54'}


save_live_month_54 = f"{main_path}/figures/paper_figures/png/roccurve_cdt_di_fi_ohe_live_month_54.png"
paper_figure_live_month_54 = f"{main_path}/figures/paper_figures/svg/roccurve_cdt_di_fi_ohe_live_month_54.svg"
figures.draw_rocauc_curve(classifier_names, roc_scores_live_month_54, class_names_live_month_54, grid_shape=(1, 1),
                         save=save_live_month_54, paper_figure=paper_figure_live_month_54)


roc_scores_live_month_72 = {'cdt_di_fi_ohe_live_month_72':[metric_results_survival['cdt_di_fi_ohe_live_month_72']['lr']['rocauc'], metric_results_survival['cdt_di_fi_ohe_live_month_72']['rf']['rocauc'],
                   metric_results_survival['cdt_di_fi_ohe_live_month_72']['svm']['rocauc']]}

class_names_live_month_72 = {'cdt_di_fi_ohe_live_month_72':'Approach CDT_DI_FI_OHE_LIVE_MONTH_72'}


save_live_month_72 = f"{main_path}/figures/paper_figures/png/roccurve_cdt_di_fi_ohe_live_month_72.png"
paper_figure_live_month_72 = f"{main_path}/figures/paper_figures/svg/roccurve_cdt_di_fi_ohe_live_month_72.svg"
figures.draw_rocauc_curve(classifier_names, roc_scores_live_month_72, class_names_live_month_72, grid_shape=(1, 1),
                         save=save_live_month_72, paper_figure=paper_figure_live_month_72)


roc_scores_live_month_90 = {'cdt_di_fi_ohe_live_month_90':[metric_results_survival['cdt_di_fi_ohe_live_month_90']['lr']['rocauc'], metric_results_survival['cdt_di_fi_ohe_live_month_90']['rf']['rocauc'],
                   metric_results_survival['cdt_di_fi_ohe_live_month_90']['svm']['rocauc']]}

class_names_live_month_90 = {'cdt_di_fi_ohe_live_month_90':'Approach CDT_DI_FI_OHE_LIVE_MONTH_90'}


save_live_month_90 = f"{main_path}/figures/paper_figures/png/roccurve_cdt_di_fi_ohe_live_month_90.png"
paper_figure_live_month_90 = f"{main_path}/figures/paper_figures/svg/roccurve_cdt_di_fi_ohe_live_month_90.svg"
figures.draw_rocauc_curve(classifier_names, roc_scores_live_month_90, class_names_live_month_90, grid_shape=(1, 1),
                         save=save_live_month_90, paper_figure=paper_figure_live_month_90)


roc_scores_live_month_108 = {'cdt_di_fi_ohe_live_month_108':[metric_results_survival['cdt_di_fi_ohe_live_month_108']['lr']['rocauc'], metric_results_survival['cdt_di_fi_ohe_live_month_108']['rf']['rocauc'],
                   metric_results_survival['cdt_di_fi_ohe_live_month_108']['svm']['rocauc']]}

class_names_live_month_108 = {'cdt_di_fi_ohe_live_month_108':'Approach CDT_DI_FI_OHE_LIVE_MONTH_108'}


save_live_month_108 = f"{main_path}/figures/paper_figures/png/roccurve_cdt_di_fi_ohe_live_month_108.png"
paper_figure_live_month_108 = f"{main_path}/figures/paper_figures/svg/roccurve_cdt_di_fi_ohe_live_month_108.svg"
figures.draw_rocauc_curve(classifier_names, roc_scores_live_month_108, class_names_live_month_108, grid_shape=(1, 1),
                         save=save_live_month_108, paper_figure=paper_figure_live_month_108)

# %% [markdown]
# # Feature Importance

# %%
df_path = f"{main_path}/data/processed/dataframes"
cdt_di_fi_ohe = pd.read_csv(f"{df_path}/cdt_di_fi_ohe.csv")
ohe_di = pd.read_csv(f"{df_path}/ohe_di.csv")
cdt_di_fi = pd.read_csv(f"{df_path}/cdt_di_fi.csv")
cdt_di_ohe = pd.read_csv(f"{df_path}/cdt_di_ohe.csv")
ohe_di_fi = pd.read_csv(f"{df_path}/ohe_di_fi.csv")
cdt_di = pd.read_csv(f"{df_path}/cdt_di.csv")

targets = pd.read_csv(f"{df_path}/targets.csv")
binary_data = pd.read_csv(f"{df_path}/binary_data_is_live.csv")
data_live_month_18 = pd.read_csv(f"{df_path}/data_live_month_18.csv")
data_live_month_36 = pd.read_csv(f"{df_path}/data_live_month_36.csv")
data_live_month_54 = pd.read_csv(f"{df_path}/data_live_month_54.csv")
data_live_month_72 = pd.read_csv(f"{df_path}/data_live_month_72.csv")
data_live_month_90 = pd.read_csv(f"{df_path}/data_live_month_90.csv")
data_live_month_108 = pd.read_csv(f"{df_path}/data_live_month_108.csv")
print(cdt_di_fi.columns)
# Out:
# Index(['IDO-1', 'p16540', 'p16580', 'FOXP3', 'ICAM-1', 'GALECTİN-3', 'CD28',
#        'GALECTİN-3.1', 'CD27', 'PD1/pdcd1PDL1/cd274', 'PDL1', 'CD40', 'TIM1',
#        'CTLA-4', 'MDM2'],
#       dtype='object')

# %%
save = f"{main_path}/figures/paper_figures/png/feature_importance_ohe_di.png"
paper_figure = f"{main_path}/figures/paper_figures/svg/feature_importance_ohe_di.svg"
figures.feature_importance_plot(ohe_di.values, targets.values, ohe_di.columns,
                                save=save, paper_figure=paper_figure)

save_is_live = f"{main_path}/figures/paper_figures/png/feature_importance_cdt_di_fi_is_live.png"
paper_figure_is_live = f"{main_path}/figures/paper_figures/svg/feature_importance_cdt_di_fi_is_live.svg"
figures.feature_importance_plot(cdt_di_fi.values, binary_data.values, cdt_di_fi.columns,
                                save=save_is_live, paper_figure=paper_figure_is_live)

save_live_month_18 = f"{main_path}/figures/paper_figures/png/feature_importance_cdt_di_live_month_18.png"
paper_figure_live_month_18 = f"{main_path}/figures/paper_figures/svg/feature_importance_cdt_di_live_month_18.svg"
figures.feature_importance_plot(cdt_di[0:70].values, data_live_month_18.values, cdt_di[0:70].columns,
                                save=save_live_month_18, paper_figure=paper_figure_live_month_18)

save_live_month_36 = f"{main_path}/figures/paper_figures/png/feature_importance_cdt_di_fi_live_month_36.png"
paper_figure_live_month_36 = f"{main_path}/figures/paper_figures/svg/feature_importance_cdt_di_fi_live_month_36.svg"
figures.feature_importance_plot(cdt_di_fi[0:70].values, data_live_month_36.values, cdt_di_fi[0:70].columns,
                                save=save_live_month_36, paper_figure=paper_figure_live_month_36)


save_live_month_54 = f"{main_path}/figures/paper_figures/png/feature_importance_cdt_di_fi_live_month_54.png"
paper_figure_live_month_54 = f"{main_path}/figures/paper_figures/svg/feature_importance_cdt_di_fi_live_month_54.svg"
figures.feature_importance_plot(cdt_di_fi[0:70].values, data_live_month_54.values, cdt_di_fi[0:70].columns,
                                save=save_live_month_54, paper_figure=paper_figure_live_month_54)


save_live_month_72 = f"{main_path}/figures/paper_figures/png/feature_importance_ohe_di_fi_live_month_72.png"
paper_figure_live_month_72 = f"{main_path}/figures/paper_figures/svg/feature_importance_ohe_di_fi_live_month_72.svg"
figures.feature_importance_plot(ohe_di_fi[0:70].values, data_live_month_72.values, ohe_di_fi[0:70].columns,
                                save=save_live_month_72, paper_figure=paper_figure_live_month_72)


save_live_month_90 = f"{main_path}/figures/paper_figures/png/feature_importance_cdt_di_fi_ohe_live_month_90.png"
paper_figure_live_month_90 = f"{main_path}/figures/paper_figures/svg/feature_importance_cdt_di_fi_ohe_live_month_90.svg"
figures.feature_importance_plot(cdt_di_fi_ohe[0:70].values, data_live_month_90.values, cdt_di_fi_ohe[0:70].columns,
                                save=save_live_month_90, paper_figure=paper_figure_live_month_90)


save_live_month_108 = f"{main_path}/figures/paper_figures/png/feature_importance_cdt_di_fi_ohe_live_month_108.png"
paper_figure_live_month_108 = f"{main_path}/figures/paper_figures/svg/feature_importance_cdt_di_fi_ohe_live_month_108.svg"
figures.feature_importance_plot(cdt_di_fi_ohe[0:70].values, data_live_month_108.values, cdt_di_fi_ohe[0:70].columns,
                                save=save_live_month_108, paper_figure=paper_figure_live_month_108)
# Out:
# /Users/utku/Desktop/CE/bioinformatics lab/Lung_Cancer/src/notebooks/figures/../../../src/scripts/common_figures.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(X_train_std, y)
# /Users/utku/Desktop/CE/bioinformatics lab/Lung_Cancer/src/notebooks/figures/../../../src/scripts/common_figures.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(X_train_std, y)
# /Users/utku/Desktop/CE/bioinformatics lab/Lung_Cancer/src/notebooks/figures/../../../src/scripts/common_figures.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(X_train_std, y)
# ...

# %% [markdown]
# # Decision Boundaries

# %%
classifier_titles = ['LR', 'RF', 'SVM']
classifiers = [metric_results['ohe_di'][i.lower()]['best_estimator'] for i in classifier_titles]

save = f"{main_path}/figures/paper_figures/png/decision_boundaries_ohe_di.png"
paper_figure = f"{main_path}/figures/paper_figures/svg/decision_boundaries_ohe_di.svg"
figures.plot_decision_boundaries(ohe_di.values, targets.values.ravel(), 
                                 classifiers, classifier_titles, actual_labels=['Healthy', 'Cancer'],
                                save=save, paper_figure=paper_figure)

classifiers_is_live = [metric_results['cdt_di_fi_is_live'][i.lower()]['best_estimator'] for i in classifier_titles]

save_is_live = f"{main_path}/figures/paper_figures/png/decision_boundaries_cdt_di_fi_is_live.png"
paper_figure_is_live = f"{main_path}/figures/paper_figures/svg/decision_boundaries_cdt_di_fi_is_live.svg"
figures.plot_decision_boundaries(cdt_di_fi.values, binary_data.values.ravel(), 
                                 classifiers, classifier_titles, actual_labels=['Dead', 'Live'],
                                save=save_is_live, paper_figure=paper_figure_is_live)



classifiers_live_month_18 = [metric_results_survival['cdt_di_live_month_18'][i.lower()]['best_estimator'] for i in classifier_titles]

save_live_month_18 = f"{main_path}/figures/paper_figures/png/decision_boundaries_cdt_di_live_month_18.png"
paper_figure_live_month_18 = f"{main_path}/figures/paper_figures/svg/decision_boundaries_cdt_di_live_month_18.svg"
figures.plot_decision_boundaries(cdt_di[0:70].values, data_live_month_18.values.ravel(), 
                                 classifiers, classifier_titles, actual_labels=['Less 18 Months', 'More 18 Months'],
                                save=save_live_month_18, paper_figure=paper_figure_live_month_18)


classifiers_live_month_36 = [metric_results_survival['cdt_di_fi_live_month_36'][i.lower()]['best_estimator'] for i in classifier_titles]

save_live_month_36 = f"{main_path}/figures/paper_figures/png/decision_boundaries_cdt_di_fi_live_month_36.png"
paper_figure_live_month_36 = f"{main_path}/figures/paper_figures/svg/decision_boundaries_cdt_di_fi_live_month_36.svg"
figures.plot_decision_boundaries(cdt_di_fi[0:70].values, data_live_month_36.values.ravel(), 
                                 classifiers, classifier_titles, actual_labels=['Less 36 Months', 'More 36 Months'],
                                save=save_live_month_36, paper_figure=paper_figure_live_month_36)


classifiers_live_month_54 = [metric_results_survival['cdt_di_fi_ohe_live_month_54'][i.lower()]['best_estimator'] for i in classifier_titles]

save_live_month_54 = f"{main_path}/figures/paper_figures/png/decision_boundaries_cdt_di_fi_live_month_54.png"
paper_figure_live_month_54 = f"{main_path}/figures/paper_figures/svg/decision_boundaries_cdt_di_fi_live_month_54.svg"
figures.plot_decision_boundaries(cdt_di_fi[0:70].values, data_live_month_54.values.ravel(), 
                                 classifiers, classifier_titles, actual_labels=['Less 54 Months', 'More 54 Months'],
                                save=save_live_month_54, paper_figure=paper_figure_live_month_54)


classifiers_live_month_72 = [metric_results_survival['cdt_di_fi_ohe_live_month_72'][i.lower()]['best_estimator'] for i in classifier_titles]

save_live_month_72 = f"{main_path}/figures/paper_figures/png/decision_boundaries_ohe_di_fi_live_month_72.png"
paper_figure_live_month_72 = f"{main_path}/figures/paper_figures/svg/decision_boundaries_ohe_di_fi_live_month_72.svg"
figures.plot_decision_boundaries(ohe_di_fi[0:70].values, data_live_month_72.values.ravel(), 
                                 classifiers, classifier_titles, actual_labels=['Less 72 Months', 'More 72 Months'],
                                save=save_live_month_72, paper_figure=paper_figure_live_month_72)


classifiers_live_month_90 = [metric_results_survival['cdt_di_fi_ohe_live_month_90'][i.lower()]['best_estimator'] for i in classifier_titles]

save_live_month_90 = f"{main_path}/figures/paper_figures/png/decision_boundaries_cdt_di_fi_ohe_live_month_90.png"
paper_figure_live_month_90 = f"{main_path}/figures/paper_figures/svg/decision_boundaries_cdt_di_fi_ohe_live_month_90.svg"
figures.plot_decision_boundaries(cdt_di_fi_ohe[0:70].values, data_live_month_90.values.ravel(), 
                                 classifiers, classifier_titles, actual_labels=['Less 90 Months', 'More 90 Months'],
                                save=save_live_month_90, paper_figure=paper_figure_live_month_90)


classifiers_live_month_108 = [metric_results_survival['cdt_di_fi_ohe_live_month_108'][i.lower()]['best_estimator'] for i in classifier_titles]

save_live_month_108 = f"{main_path}/figures/paper_figures/png/decision_boundaries_cdt_di_fi_ohe_live_month_108.png"
paper_figure_live_month_108 = f"{main_path}/figures/paper_figures/svg/decision_boundaries_cdt_di_fi_ohe_live_month_108.svg"
figures.plot_decision_boundaries(cdt_di_fi_ohe[0:70].values, data_live_month_108.values.ravel(), 
                                 classifiers, classifier_titles, actual_labels=['Less 108 Months', 'More 108 Months'],
                                save=save_live_month_108, paper_figure=paper_figure_live_month_108)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mlxtend/plotting/decision_regions.py:315: UserWarning: No contour levels were found within the data range.
#   ax.contour(xx, yy, Z, cset.levels, **contour_kwargs)
